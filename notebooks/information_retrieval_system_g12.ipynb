# %%
# !pip install transformers torch accelerate bitsandbytes peft trl datasets sentence_transformers faiss-gpu-cu11==1.10.0 numpy pandas
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Collecting trl
#   Downloading trl-0.17.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Collecting faiss-gpu-cu11==1.10.0
#   Downloading faiss_gpu_cu11-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting numpy
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu11==1.10.0) (24.2)
# Collecting nvidia-cuda-runtime-cu11>=11.8.89 (from faiss-gpu-cu11==1.10.0)
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cublas-cu11>=11.11.3.6 (from faiss-gpu-cu11==1.10.0)
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl) (13.9.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (2.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Downloading faiss_gpu_cu11-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 MB 50.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 47.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 114.6 MB/s eta 0:00:00
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 32.8 MB/s eta 0:00:00
# Downloading trl-0.17.0-py3-none-any.whl (348 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.0/348.0 kB 35.9 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 45.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 108.9 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 21.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (875 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 63.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cublas-cu11, numpy, fsspec, nvidia-cusparse-cu12, nvidia-cudnn-cu12, faiss-gpu-cu11, nvidia-cusolver-cu12, datasets, bitsandbytes, trl
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed bitsandbytes-0.45.5 datasets-3.6.0 faiss-gpu-cu11-1.10.0 fsspec-2025.3.0 numpy-1.26.4 nvidia-cublas-cu11-11.11.3.6 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 trl-0.17.0

# %%
from huggingface_hub import login
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

if HF_TOKEN is None:
    raise ValueError("HF_TOKEN environment variable not set.")

login(token=HF_TOKEN)

# %% [markdown]
# # Cargando el decoder tuneado

# %%
import torch
import numpy  as np
import json
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel

#El ID del modelo Llama BASE
base_model_id = "meta-llama/Llama-3.2-1B"
adapter_and_tokenizer_path = "/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/decoder/final_adapter"

# Determinar el dispositivo
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Usando dispositivo: {device}")


model_base = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    device_map="auto",
    trust_remote_code=True
)

print("Modelo base cargado.")

# --- Cargar el Tokenizador ---
# El tokenizador se guardó junto con el adaptador.
print(f"Cargando el tokenizador desde: {adapter_and_tokenizer_path}...")
tokenizer = AutoTokenizer.from_pretrained(adapter_and_tokenizer_path, trust_remote_code=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    model_base.config.pad_token_id = model_base.config.eos_token_id
print("Tokenizador cargado.")

# --- Cargar y Aplicar el Adaptador LoRA ---
print(f"Cargando y aplicando el adaptador LoRA desde: {adapter_and_tokenizer_path}...")
model_tuned = PeftModel.from_pretrained(model_base, adapter_and_tokenizer_path)
print("Adaptador LoRA cargado y aplicado al modelo base.")

# --- Preparar el Modelo para Inferencia ---
model_tuned.eval()
print("Modelo fine-tuneado listo para inferencia.")
# Out:
# Usando dispositivo: cuda
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# Modelo base cargado.
# Cargando el tokenizador desde: /content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/decoder/final_adapter...
# Tokenizador cargado.
# Cargando y aplicando el adaptador LoRA desde: /content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/decoder/final_adapter...
# Adaptador LoRA cargado y aplicado al modelo base.
# Modelo fine-tuneado listo para inferencia.

# %% [markdown]
# # Cargando encoder construido

# %%
def load_json_to_dataset(file_path):
  try:
    with open(file_path, 'r') as f:
      data = json.load(f)
  except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    return None

  dataset = Dataset.from_dict(data)
  return dataset

file_path = '/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/pubmed_500K.json'
pubmed_dataset = load_json_to_dataset(file_path)
if pubmed_dataset:
  print(pubmed_dataset[0])
# Out:
# {'id': 'pubmed23n0001_0', 'title': "[Biochemical studies on camomile components/III. In vitro studies about the antipeptic activity of (--)-alpha-bisabolol (author's transl)].", 'content': '(--)-alpha-Bisabolol has a primary antipeptic action depending on dosage, which is not caused by an alteration of the pH-value. The proteolytic activity of pepsin is reduced by 50 percent through addition of bisabolol in the ratio of 1/0.5. The antipeptic action of bisabolol only occurs in case of direct contact. In case of a previous contact with the substrate, the inhibiting effect is lost.', 'contents': "[Biochemical studies on camomile components/III. In vitro studies about the antipeptic activity of (--)-alpha-bisabolol (author's transl)]. (--)-alpha-Bisabolol has a primary antipeptic action depending on dosage, which is not caused by an alteration of the pH-value. The proteolytic activity of pepsin is reduced by 50 percent through addition of bisabolol in the ratio of 1/0.5. The antipeptic action of bisabolol only occurs in case of direct contact. In case of a previous contact with the substrate, the inhibiting effect is lost.", 'PMID': 21}

# %%
import random
import faiss
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from sentence_transformers import SentenceTransformer
from peft import PeftModel
import re # Para parsear la salida del LLM

ENCODER_MODEL_NAME = "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext"
FAISS_INDEX_PATH = "/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/encoder/pubmed_faiss_pubmedbert_20250516_020433.index" # El índice FAISS que creaste
PUBMED_CORPUS_FILE_PATH = '/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/pubmed_500K.json' # Para cargar los textos originales

# Archivo de preguntas de prueba
TEST_QUESTIONS_FILE_PATH = '/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/pubmed_QA_test_questions.json'

# Otros parámetros
TOP_K_RETRIEVAL = 5 # Número de documentos a recuperar
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Usando dispositivo general: {DEVICE}")


# --- 1. CARGAR COMPONENTES DEL ENCODER (RETRIEVAL) ---
print("\n--- Cargando Componentes del Encoder (Retrieval) ---")

encoder_model = SentenceTransformer(ENCODER_MODEL_NAME, device=DEVICE)
print(f"Encoder '{ENCODER_MODEL_NAME}' cargado.")

faiss_index = faiss.read_index(FAISS_INDEX_PATH)
print(f"Índice FAISS cargado desde '{FAISS_INDEX_PATH}'. Total de vectores: {faiss_index.ntotal}")

# Cargar los textos originales del corpus
all_doc_texts = []
all_doc_ids_corpus = []

# Extraer los textos y los IDs
texts_list = pubmed_dataset['contents']
doc_ids_list = pubmed_dataset['PMID']
doc_ids_list = [str(pmid) for pmid in doc_ids_list]

#Filtrado de textos vacios o None
filtered_texts = []
filtered_doc_ids = []

for text, doc_id in zip(texts_list, doc_ids_list):
    if text and text.strip():  # Verifica que no sea None y que no esté vacío después de quitar espacios
        filtered_texts.append(text)
        filtered_doc_ids.append(doc_id)
    else:
        print(f"Advertencia: Documento con ID {doc_id} tiene campo 'contents' vacío o nulo. Será omitido.")

all_doc_texts = filtered_texts
all_doc_ids_corpus = filtered_doc_ids

if not all_doc_texts or len(all_doc_texts) != faiss_index.ntotal:
    raise ValueError(f"El número de textos cargados ({len(all_doc_texts)}) no coincide con el total del índice FAISS ({faiss_index.ntotal}). Verifica el procesamiento de {PUBMED_CORPUS_FILE_PATH}.")
print(f"Textos del corpus ({len(all_doc_texts)} documentos) cargados y listos.")
# Out:
# Usando dispositivo general: cuda
#
# --- Cargando Componentes del Encoder (Retrieval) ---
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Encoder 'microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext' cargado.
# Índice FAISS cargado desde '/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/encoder/pubmed_faiss_pubmedbert_20250516_020433.index'. Total de vectores: 500000
# Textos del corpus (500000 documentos) cargados y listos.

# %% [markdown]
# # Construccion de sistema de busqueda de informacion RAG

# %%
def retrieve_relevant_documents(query_text: str) -> list[str]:
  """
  Recupera los textos de los documentos más relevantes para una consulta.
  """
  INTERNAL_SEARCH_K = 5 # Siempre buscar los 5 mejores internamente
  query_embedding = encoder_model.encode([query_text], convert_to_numpy=True)
  distances, faiss_indices = faiss_index.search(query_embedding, INTERNAL_SEARCH_K)
  best_doc_original_index = faiss_indices[0][0]
  best_doc_distance = distances[0][0]

  if 0 <= best_doc_original_index < len(all_doc_texts):
    best_doc_text = all_doc_texts[best_doc_original_index]

    # print(f"  Mejor contexto seleccionado (distancia {best_doc_distance:.4f}): {best_doc_text[:100]}...")
    return best_doc_text
  else:
    print(f"Advertencia: No se encontraron documentos relevantes para la consulta '{query_text}'.")
    return []

# %%
def format_inference_prompt(question: str, options: list[str], retrieved_context) -> str:

  opciones_texto = ""
  for i, opcion_txt in enumerate(options):
      opciones_texto += f"{i}: {opcion_txt}\n"

  prompt = (
    f"Context: {retrieved_context}\n\n"
    f"Question: {question}\n\n"
    f"Options:\n{opciones_texto.strip()}\n\n"
    f"Based on the context and the question, what is the ID of the correct option?\n"
    f"Answer:"
  )

  return prompt

def get_predicted_option_id(
    question_text: str,
    option_texts: list[str],
    retrieved_contexts: list[str]
) -> str:
    inference_prompt = format_inference_prompt(question_text, option_texts, retrieved_contexts)

    max_generation_length = 5 # Para generar solo el ID "0", "1", "2", o "3"
    max_input_len = model_tuned.config.max_position_embeddings - max_generation_length

    valid_choices = ["0", "1", "2", "3"]
    choice_token_ids = [tokenizer(x, add_special_tokens=False)["input_ids"][0] for x in valid_choices]

    inputs = tokenizer(inference_prompt, return_tensors="pt").to(model_tuned.device)

    model_tuned.eval()
    with torch.no_grad():
        outputs = model_tuned(**inputs)
        logits = outputs.logits[:, -1, :]
        filtered_logits = logits[:, choice_token_ids]
        probs = torch.softmax(filtered_logits, dim=-1)
        pred_index = torch.argmax(probs, dim=-1).item()
        return valid_choices[pred_index]

# %%
#importar datos de prueba desde pumed_QA_test_questions.json
test_questions_data = []
try:
    with open(TEST_QUESTIONS_FILE_PATH, 'r', encoding='utf-8') as f_test:
        for line in f_test:
            test_questions_data.append(json.loads(line.strip()))
    print(f"Cargadas {len(test_questions_data)} preguntas de prueba.")
    print(test_questions_data[0])
except Exception as e:
    print(f"Error cargando el archivo de preguntas de prueba: {e}")
    exit()
# Out:
# Cargadas 1000 preguntas de prueba.
# {'id': 26, 'question': 'What were the findings regarding alpha-1-antitrypsin deficiency of genotype PiZ in an autopsy series of 238 individuals?', 'option': ['Alpha-1-antitrypsin deficiency of genotype PiZ was found in 30 cases, with no significant association with pulmonary emphysema.', 'In an autopsy series of 238 individuals, alpha-1-antitrypsin deficiency of genotype PiZ was identified in 15 cases, with a higher prevalence of pulmonary emphysema among heterozygous individuals.', 'In the autopsy series, alpha-1-antitrypsin deficiency of genotype PiZ was identified in 5 cases, all of whom were homozygous.', 'The study found that alpha-1-antitrypsin deficiency of genotype PiZ was present in 20 cases, with a higher prevalence of liver disease among heterozygous individuals.']}

# %%
# PROCESAR PREGUNTAS DE PRUEBA
print(f"\n--- Procesando Preguntas de Prueba ---")
results = []
for i, test_item in enumerate(test_questions_data):
    question_id = test_item.get("id")
    question_text = test_item.get("question")
    option_texts = test_item.get("option") # Lista de 4 strings

    if not all([question_id, question_text, option_texts]) or len(option_texts) != 4:
        print(f"Saltando ítem de prueba inválido o incompleto (índice {i}): {test_item}")
        continue

    print(f"\nProcesando Pregunta ID: {question_id} ({i+1}/{len(test_questions_data)})")
    print(f"  Pregunta: {question_text}")

    # a. Recuperar contextos
    retrieved_context = retrieve_relevant_documents(question_text)
    if not retrieved_context:
        print(f"  No se recuperaron contextos para la pregunta ID: {question_id}. Llama podría no tener suficiente información.")

    # b. Obtener predicción del ID de respuesta de Llama
    predicted_id = get_predicted_option_id(question_text, option_texts, retrieved_context)
    print(f"  ID de respuesta predicho por Llama: {predicted_id}")

    results.append({
        "ID": question_id,
        "answer": predicted_id
    })

# --- 4. MOSTRAR O GUARDAR RESULTADOS ---
print("\n\n--- Resultados Finales ---")
for result in results:
    print(f"Pregunta ID: {result['ID']}, Predicción ID: {result['answer']}")

# Opcional: Guardar resultados en un archivo JSON
results_output_path = "/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/rag_test_predictions.json"
with open(results_output_path, 'w', encoding='utf-8') as f_out:
    json.dump(results, f_out, indent=2, ensure_ascii=False)
print(f"\nResultados completos guardados en: {results_output_path}")

print("\n--- Proceso Completado ---")
# Out:
# Streaming output truncated to the last 5000 lines.
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 37 (3/1000)
#   Pregunta: What effects do antipsychotic drugs have on rats with biochemically induced abnormal behavior, as shown by the administration of L-Dopa and pimozide?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 70 (4/1000)
#   Pregunta: What are the characteristics and behaviors of gonadotroph-rich cell lines derived from multipotential pituitary clonal cells (2A8) when implanted under the kidney capsule of hypophysectomized female rats?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 109 (5/1000)
#   Pregunta: What were the findings regarding urinary calcium excretion in healthy males with varying protein intake and calcium supplementation in a study on calcium metabolism?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 182 (6/1000)
#   Pregunta: What were the findings regarding the association of clinical filariasis and Wuchereria bancrofti infections in a Jakarta study conducted from 1969 to 1977?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 234 (7/1000)
#   Pregunta: What findings were observed in infant rats regarding bacteremia and its relationship to cerebrospinal fluid cultures and inflammatory responses after intranasal inoculation of Haemophilus influenzae type b?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 274 (8/1000)
#   Pregunta: What is the pattern of enzyme activity observed in human red blood cells over a 24-hour period?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 276 (9/1000)
#   Pregunta: What were the findings in a case of mercuric chloride intoxication regarding urinary albumin and beta2 microglobulin levels, and what do these findings suggest about renal function?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 320 (10/1000)
#   Pregunta: What did in vivo studies reveal about the accumulation of 5alpha-dihydroprogesterone in the pituitary and hypothalamus of rats?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 417 (11/1000)
#   Pregunta: What did a study of seven patients find regarding the relationship between ocular colobomata and congenital heart disease?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 481 (12/1000)
#   Pregunta: What effect does lynoestrenol 0.5 mg daily have on ovulation and the function of the corpora lutea?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 505 (13/1000)
#   Pregunta: What did the study of an excised testis from a 14 1/2-year-old girl with incomplete testicular feminization syndrome reveal about the relationship between germ cell carcinomas and intratubular germ cell abnormalities?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 507 (14/1000)
#   Pregunta: How do dietary habits impact the development of cancers such as colon and breast cancer, and what does this imply for cancer research?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 530 (15/1000)
#   Pregunta: What should be considered when using colloidal plasma substitutes for volume replacement therapy, despite their low incidence of anaphylactoid complications?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 565 (16/1000)
#   Pregunta: What does the study reveal about the development and structural changes of the marginal net of the rabbit's tectorial membrane?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 570 (17/1000)
#   Pregunta: What were the findings regarding liver and kidney damage in young steers infected with Theileria annulata, and how effective were liver-protecting medications in this clinical study?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 581 (18/1000)
#   Pregunta: What effect does the administration of oral neomycin or kanamycin have on urea degradation and renal function in chronic uremic patients?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 596 (19/1000)
#   Pregunta: What did a study of 73 patients with chronic digestive organ diseases reveal about the effectiveness of the desferal test for assessing iron reserves?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 610 (20/1000)
#   Pregunta: What are the reported risks associated with barium contrast examinations in patients with a competent ileocecal valve?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 641 (21/1000)
#   Pregunta: What is the process by which bovine factor VII is converted to factor VIIa, and what role does factor XIIa play in this conversion?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 651 (22/1000)
#   Pregunta: What did electron microscopy reveal about the relationship between autophagic vacuoles, residual bodies, and the endoplasmic reticulum in rat hepatocytes under both normal and hyperplastic conditions?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 691 (23/1000)
#   Pregunta: How does the required daily dose of lithium therapy differ between older patients and those under 50 years of age?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 721 (24/1000)
#   Pregunta: What is the relationship between precipitins, complement activation, and the etiology of allergic lung disease caused by inhaled moldy particles?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 733 (25/1000)
#   Pregunta: What is the clean-up procedure for extracting soil samples to determine 2,3,7,8-tetrachlorodibenzo-p-dioxin?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 847 (26/1000)
#   Pregunta: What were the findings of a retrospective analysis regarding the five-year survival rates of patients with significant coronary artery stenosis?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 888 (27/1000)
#   Pregunta: What effect does whole-body X-irradiation have on liver RNA synthesis in rats, and how is this effect influenced by the removal of the adrenal glands?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 909 (28/1000)
#   Pregunta: What do lipid-protein interactions in model membranes from bovine brain white matter reveal about the orientation of lipids at varying temperatures?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 914 (29/1000)
#   Pregunta: What are the differences in receptor presence for C3 and IgG among macrophage, neutrophil, and eosinophil colony cells, and how does this vary with the age of the colonies?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 926 (30/1000)
#   Pregunta: What were the findings regarding the amino-terminal sequences of indoleglycerol phosphate synthetase from Escherichia coli and Salmonella typhimurium?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 938 (31/1000)
#   Pregunta: What is the most effective treatment for anorexia nervosa, according to recent findings on hospital-based operant conditioning programs?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1007 (32/1000)
#   Pregunta: What did the authors report regarding the treatment of a patient with secondary traumatic glaucoma due to cystic epithelial invasion of the anterior chamber?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1013 (33/1000)
#   Pregunta: What are intracranial cavernous angiomas and how can they be identified through imaging techniques?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1014 (34/1000)
#   Pregunta: What did a controlled polygraphic study reveal about the effects of gently oscillating water beds on apnea and bradycardia in preterm infants during sleep?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 1041 (35/1000)
#   Pregunta: What were the findings of the study regarding the effectiveness and side effects of indomethacin in treating primary dysmenorrhea?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 1050 (36/1000)
#   Pregunta: What effect does acetylcholine have on potassium-induced increases in water and sodium uptake in rat cerebral cortex slices, and what are the requirements for this effect?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1076 (37/1000)
#   Pregunta: What were the findings of the 1977 national survey regarding changes in academic departments of obstetrics and gynecology in North America compared to 1968?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 1077 (38/1000)
#   Pregunta: What does the National League for Nursing do each year to gather statistics on nursing education in the U.S.?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1109 (39/1000)
#   Pregunta: What did a comparative study reveal about the activity levels of erythrocytic superoxide dismutase-AJ and phosphoglucomutase in individuals with trisomy 21 compared to normal subjects?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 1126 (40/1000)
#   Pregunta: What were the false-negative and false-positive rates found in the transtracheal aspiration bacteriologic studies conducted on 488 patients?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1142 (41/1000)
#   Pregunta: What does the understanding of metabolic energy transformation reveal about the role of phosphate and ATP in anaerobic and aerobic systems?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1158 (42/1000)
#   Pregunta: What are the characteristics and steroid production differences of the two types of cells found in the enriched fraction of rat adrenal zona reticularis?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1160 (43/1000)
#   Pregunta: What were the findings regarding the average resistance and performance of Heidbrink-type expiratory valves in clinical use?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1248 (44/1000)
#   Pregunta: What are the differences in the lifespan and characteristics of heterogeneous nuclear RNA between normal small lymphocytes and leukemic blast cells?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 1332 (45/1000)
#   Pregunta: What are the key findings regarding tyrosyl-tRNA synthetase from wild type Drosophila in terms of its ability to differentiate between tRNATyr of wild type and the suppressor mutant su(s)2, as well as its kinetic parameters, heat stability, and molecular weight compared to similar enzymes from other organisms?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1333 (46/1000)
#   Pregunta: What does the study reveal about the effects of acetylcholine antagonists on Aplysia neurones, particularly regarding the 'elementary current' and the modifications of ACh-induced current relaxations?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1416 (47/1000)
#   Pregunta: What are the dietary protein recommendations for patients with chronic diffuse glomerulonephritis and nephrotic syndrome?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 1483 (48/1000)
#   Pregunta: What did a study on the lives of 10 classical composers reveal about the factors influencing their total productivity?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 1491 (49/1000)
#   Pregunta: What was observed in a patient who developed profound thrombocytopenia during heparin treatment, and how did the condition respond to the cessation and re-administration of the drug?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 1588 (50/1000)
#   Pregunta: What are the key features and advantages of the novel ultrasonic real-time scanner described in the paper?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 1613 (51/1000)
#   Pregunta: What was the effect of 24-hour exposure to electrostatic and magnetic fields on the frequency of sex-linked recessive lethal mutations in mature sperm of Canton-S Drosophila melanogaster males?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1668 (52/1000)
#   Pregunta: What does the study reveal about the relationship between paraplegia and bilharziasis, particularly regarding spinal cord involvement and the importance of diagnosis?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1687 (53/1000)
#   Pregunta: What were the findings of the long-term study on patients with displaced acetabular fractures regarding the outcomes of surgical versus non-surgical treatment?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 1713 (54/1000)
#   Pregunta: What are the characteristics and treatment options for male breast cancer?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 1752 (55/1000)
#   Pregunta: What were the distinct periods of psychopathologic and neurologic syndromes identified in a study of patients with closed skull and brain trauma?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1769 (56/1000)
#   Pregunta: What did the immunoferritin labeling study reveal about the expression and distribution of H-2 antigens in epithelial cells?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 1784 (57/1000)
#   Pregunta: What does the immunogenetic study on mink's serum low-density lipoprotein suggest about the genetic basis for a new alloantigenic marker?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1811 (58/1000)
#   Pregunta: At what stage of gestation were immunoreactive cells for beta-lipotropin and beta-endorphins detected in human fetal pituitary glands, and were any of these cells found in anencephalic fetuses?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 1856 (59/1000)
#   Pregunta: What were the effects of gymnemic acid on the taste responses to sucrose in hamsters and rats?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 1887 (60/1000)
#   Pregunta: What are the relative accretion rates for zinc and calcium in endochondral bone, calcifying cartilage, and cortical bone in growing rats?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2050 (61/1000)
#   Pregunta: What were the comparative activities of josamycin, rosamicin, erythromycin, and clindamycin against aerobic and anaerobic organisms?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2094 (62/1000)
#   Pregunta: What procedure has shown effectiveness in treating esophagitis and preventing regurgitation in both experimental dog models and clinical patients with hiatal hernia and achalasia?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2101 (63/1000)
#   Pregunta: What were the distinct tumor patterns observed in the malignant ovarian tumor of a 25-year-old woman?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2118 (64/1000)
#   Pregunta: What is the effect of ergot alkaloids, specifically ergocorine and ergocristine, on prolactin secretion in adult female rats?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2129 (65/1000)
#   Pregunta: What were the effects of serum from rabbits on different durations of an atherogenic diet on antibody formation in intact animals, and how did Trasylol affect these properties?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2185 (66/1000)
#   Pregunta: What were the findings of the follow-up study on patients who underwent sagittal splitting of the mandibular ramus one year post-operation?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2199 (67/1000)
#   Pregunta: What were the findings regarding the synergistic effects of NM, VCR, BCNU, and DTIC in relation to different injection routes in a study of immunochemotherapeutic synergism?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2232 (68/1000)
#   Pregunta: What do gamma-bin mutants of corynebacteriophage gamma demonstrate regarding their ability to replicate in C7(beta) cells under different conditions?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2239 (69/1000)
#   Pregunta: What method was developed for the simultaneous and sensitive measurement of daunorubicin and its metabolite daunorubicinol in human plasma?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2243 (70/1000)
#   Pregunta: What were the findings regarding arterial pressures in a study of Nigerian women in early pregnancy compared to non-pregnant women and primigravidae from Aberdeen, and what was the impact on the incidence of pre-eclampsia and eclampsia?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2261 (71/1000)
#   Pregunta: What physiological changes in older rats contribute to lipid accumulation in adipose tissue?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2267 (72/1000)
#   Pregunta: What is the effect of ambulatory activity and a 6-month period on the mental function of elderly individuals with postural hypotension?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2319 (73/1000)
#   Pregunta: What effect does cycloheximide have on SV40 DNA synthesis in infected cells?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2320 (74/1000)
#   Pregunta: What were the findings regarding the histological characteristics and epidermal thickness in psoriasis plaques based on a study of biopsies from psoriasis patients?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2321 (75/1000)
#   Pregunta: What are the benefits of using a modified radioallergosorbent test (RAST) with a multiple automated sample harvester, according to a comparative study?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2364 (76/1000)
#   Pregunta: What advancements have been made in in vitro feeding techniques for rearing tsetse flies, and what factors influence female longevity and puparia weight?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2371 (77/1000)
#   Pregunta: What was the impact of the introduction of anesthesia in 1846 on the advancement of surgery, and what additional factors contributed to significant progress in the field?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2443 (78/1000)
#   Pregunta: What is the hypothesized major cause of prostatitis related to bacterial entry following sexual activities or masturbation?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2453 (79/1000)
#   Pregunta: What did a study of 31 patients with polycystic ovary syndrome reveal about the relationship between histologic abnormalities and biochemical features related to ovarian hyperandrogenism?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2454 (80/1000)
#   Pregunta: What were the findings regarding genetic and anthropogenetic differences among populations in the Mezen District of the Archangelsk Region based on a study of genetic markers and demographic traits?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2472 (81/1000)
#   Pregunta: What are the effects of theophylline therapy on renal function in premature infants with idiopathic apnea?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2497 (82/1000)
#   Pregunta: What are the central actions of pizotifen in relation to serotonin receptors, and how do they correlate with its effectiveness in classic antidepressant tests?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2520 (83/1000)
#   Pregunta: What were the findings of the study on guinea pigs regarding the effects of white noise on acoustic biopotentials?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2586 (84/1000)
#   Pregunta: What is the significance of retrograde endoscopic cholangiography in the diagnosis and treatment of biliary tract diseases compared to traditional radiological methods?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2620 (85/1000)
#   Pregunta: What did the study reveal about the effects of polyethylene oxide at 20% concentration on ovarian function during a controlled freezing process?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2668 (86/1000)
#   Pregunta: What were the findings of the study regarding the effects of age on strength and endurance in healthy men?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2675 (87/1000)
#   Pregunta: What were the findings regarding serum zinc, copper, and ceruloplasmin levels in a study comparing diabetics to normal individuals?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2719 (88/1000)
#   Pregunta: What is the mechanism by which phenethylbiguanide (PEBG) exerts its hypoglycemic activity in liver mitochondria of rats treated with glucagon?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2759 (89/1000)
#   Pregunta: What were the results of the biological activity tests conducted on the synthesized 18-substituted progesterones?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2819 (90/1000)
#   Pregunta: What advancements have been made in the determination of thrombin, antithrombin, and heparin cofactor using the chromogenic substrate H-D-Phe-Pip-Arg-p-nitroanilide?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2827 (91/1000)
#   Pregunta: What did the authors report regarding their experience with T-shape drainage in choledochotomies?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2844 (92/1000)
#   Pregunta: What effect does UV-irradiation have on RNA synthesis in cells infected with adenovirus 5, and how does this effect differ between infected and transformed cells?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 2852 (93/1000)
#   Pregunta: What was the focus of the parasitological examination conducted in Santa Clara?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2904 (94/1000)
#   Pregunta: What were the clinical outcomes for a 38-year-old man with hypogammaglobulinemia who developed bilateral intraocular Nocardia infections following a pulmonary Nocardia asteroides infection?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2918 (95/1000)
#   Pregunta: What were the neurological complications observed following the sub-occipital injection of lipiodol during cervical myelography?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2948 (96/1000)
#   Pregunta: What is the relationship between advanced tumor growth in the thymus and glycolipid-glycosyltransferase activities in lymphoma-bearing hamsters?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 2952 (97/1000)
#   Pregunta: What were the effects of supraoptimal temperatures and elevated acidity on the biomass of Candida utilis in a chemostat culture?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2968 (98/1000)
#   Pregunta: What is the effect of methanol extraction residue of BCG on the cellular immune response in patients with stage III and IV malignant melanoma?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 2982 (99/1000)
#   Pregunta: What does the report on endosulfan cover regarding its pharmacology, toxicology, and environmental impact?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 2988 (100/1000)
#   Pregunta: What does Tanaka's paper focus on in relation to Hayashi's quantification methods and Grizzle's experimental data?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3092 (101/1000)
#   Pregunta: What is the principal UV-induced reaction observed in N4-hydroxy- and N4-methoxycytidines and N6-methoxyadenosine in neutral aqueous solutions, and what are the quantum yields for each compound?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3100 (102/1000)
#   Pregunta: What were the findings regarding neurological disturbances in a study of patients with acute intermittent porphyria?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3143 (103/1000)
#   Pregunta: What did the study conclude about the effectiveness of knowledgeable versus superficial nursing reassurance on vocal stress in patients who do not use denial as a coping mechanism?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3155 (104/1000)
#   Pregunta: What factors can exacerbate female genital tuberculosis and what measures are necessary to prevent severe complications?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3169 (105/1000)
#   Pregunta: What does this paper propose regarding the health and safety of pregnant women in the workforce?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3174 (106/1000)
#   Pregunta: What properties does Cialit exhibit against germs on contaminated aortic valve grafts, and what are its limitations regarding microbial spores and viruses?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3204 (107/1000)
#   Pregunta: What was the outcome of isolating a growth-stimulating agent from human skin fibroblast cultures?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3224 (108/1000)
#   Pregunta: What did a study reveal about the relationship between inspection time and IQ scores in nonretarded and retarded subjects?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3247 (109/1000)
#   Pregunta: What are the benefits of collaborative training in primary care settings for psychiatric and primary care residents?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3283 (110/1000)
#   Pregunta: What cognitive function is significantly impacted in patients with unilateral right brain damage, as indicated by their narrower visuoperceptual categorization span?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3331 (111/1000)
#   Pregunta: What method was found to be effective and economical for improving the work performance of attendants in a residential facility for multiply-handicapped individuals?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3359 (112/1000)
#   Pregunta: What were the outcomes reported by the authors for Kuntsher's method of blind medullary nailing with reaming and traction in the treatment of compound femoral shaft fractures?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3401 (113/1000)
#   Pregunta: What does unilateral visual loss in bright light suggest in relation to carotid artery occlusive disease?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3412 (114/1000)
#   Pregunta: What does the study in anesthetized cats suggest about the mechanism behind escape from norepinephrine-induced vasoconstriction in the intestine?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3417 (115/1000)
#   Pregunta: What factors can help ensure consistency in the morphologic evaluation of human spermatozoa across different laboratories?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3436 (116/1000)
#   Pregunta: What were the findings and recommendations of a study conducted at a university-based venereal disease clinic regarding diagnostic methods for uncomplicated urogenital and rectal gonorrhea?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3471 (117/1000)
#   Pregunta: What were the findings of the study regarding the pharmacokinetics of meperidine and normeperidine in pregnant patients during labor?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3548 (118/1000)
#   Pregunta: What are the benefits of using a TRICIN-buffered modification of the CMRL-1969 medium in cell and virus cultivation?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3589 (119/1000)
#   Pregunta: What does the paper conclude about the visual system's ability to determine curvature and torsion parameters when monocularly viewing rotating three-dimensional objects?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3636 (120/1000)
#   Pregunta: What did the study reveal about the assembly pattern of flagellin molecules in different strains of Escherichia coli and the source of variations in their surface structure?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3669 (121/1000)
#   Pregunta: What was evaluated for excystment and cysticidal activity against Schizopyrenus russelli in the study on potential biologically active agents?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3678 (122/1000)
#   Pregunta: What are the key characteristics and typical onset age of symptoms for Fibrodysplasia ossificans progressiva in children?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3687 (123/1000)
#   Pregunta: What are the cardiovascular effects of morphine on cats at different dosage levels, and how do the adrenal glands influence these effects?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 3765 (124/1000)
#   Pregunta: What did a study on cats reveal about the relationship between visual inhibition of labyrinthine nystagmus and the visual cortex or superior colliculi?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 3794 (125/1000)
#   Pregunta: How do birefringence changes in rod outer segments after bleaching differ between intact and ruptured outer segment envelope membranes?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3802 (126/1000)
#   Pregunta: What method has been developed to determine phenobarbital in human saliva, and what are its precision and recovery rates for a 60-ng sample?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3806 (127/1000)
#   Pregunta: What is the effect of progesterone on sodium excretion in normal men, and how does it relate to aldosterone?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 3841 (128/1000)
#   Pregunta: What happens during the activation of prochymosin, and how does the released N-terminal segment compare to pepsinogens from other species?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3851 (129/1000)
#   Pregunta: What advancement has been made in predicting the growth pattern of human IgG multiple myeloma based on initial tumor cell measurements?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 3883 (130/1000)
#   Pregunta: What happens to malaria parasites in sickle cell hemoglobin homozygous red cells compared to heterozygous cells?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3894 (131/1000)
#   Pregunta: What did a study of 53 healthy US Air Force aircrewmen reveal about the relationship between age and G tolerance?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 3912 (132/1000)
#   Pregunta: What were the findings regarding udder infections in dairy cows with low and high rates of infection in a comparative study?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 3917 (133/1000)
#   Pregunta: Which compound has been shown to effectively counteract lethal poisoning in mice caused by alpha-amanitine or phalloidine, while other tested compounds like taxifolin, coniferyl alcohol, fisetin, and (+)-catechin were ineffective?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3989 (134/1000)
#   Pregunta: What do chest radiographs reveal about the correlation with end-diastolic pulmonary artery pressure in patients experiencing acute myocardial infarction?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 3992 (135/1000)
#   Pregunta: What did a survey of American dental schools reveal about the emphasis on teaching genetics at different educational levels and the need for trained orofacial geneticists?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4005 (136/1000)
#   Pregunta: What was the purpose of the study conducted on medical technology administration and supervision?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4013 (137/1000)
#   Pregunta: What were the findings regarding glucocorticoid binding macromolecules in chicken liver cytosol?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4138 (138/1000)
#   Pregunta: What are the effects of chronic clofibrate administration on liver and muscle metabolism in rats?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4139 (139/1000)
#   Pregunta: What are the potential links between insomnia and sleep-induced apnea in nonobese patients who snore, and what considerations should be made regarding the prescription of central nervous system depressants?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4151 (140/1000)
#   Pregunta: What does research reveal about the relationship between maxillary sinus volume and temperature in Eskimo populations?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4175 (141/1000)
#   Pregunta: What was reported in the case of an 82-year-old woman regarding her cardiac anatomy?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4310 (142/1000)
#   Pregunta: What is the plasma dopamine-beta-hydroxylase activity status in most patients with pheochromocytomas associated with multiple endocrine neoplasia Type 2?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4311 (143/1000)
#   Pregunta: What does the study using scanning electron microscopy reveal about the maturation of mechano- and chemosensitive papillae in rat tongues during postnatal development?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4326 (144/1000)
#   Pregunta: What were the findings of the comparative study regarding static urethral pressure measurements using different methods?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 4330 (145/1000)
#   Pregunta: What were the findings regarding hemoglobin concentration and blood folate levels in a prophylactic trial of iron supplements among pregnant Burmese women?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4369 (146/1000)
#   Pregunta: What has been the impact of regular staff discussions with a visiting psychotherapist in a psychiatric day hospital?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4384 (147/1000)
#   Pregunta: What treatment did a 52-year-old man with Fabry's disease undergo at age 45, and what does his follow-up indicate about the effectiveness of this treatment?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4402 (148/1000)
#   Pregunta: What were the effects of disodium etidronate treatment on gastrointestinal calcium absorption, urine calcium, bone resorption, and mineralization in postmenopausal osteoporosis patients?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4436 (149/1000)
#   Pregunta: What effect does halothane have on calcium dynamics in rat liver mitochondria?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4438 (150/1000)
#   Pregunta: What does the study on triiodothyronine receptors in thymic lymphocytes of newborn and adult rats reveal about receptor maturation?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 4445 (151/1000)
#   Pregunta: What are the physiological characteristics and achievements of a 77-year-old world champion distance runner?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4533 (152/1000)
#   Pregunta: What are the details of the two recent cases of crossed ectopia of solitary kidney reported in boys, and how do they contribute to the total number of known cases?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4554 (153/1000)
#   Pregunta: What did a study of healthy young individuals reveal about the influence of peripheral chemoreceptors on expiratory events during hypoxia?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 4555 (154/1000)
#   Pregunta: What were the findings of a review of 505 hysterosalpingograms regarding the prevalence of normal and abnormal results in infertility evaluations?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 4567 (155/1000)
#   Pregunta: What were the findings regarding the effectiveness of heparin in preventing thrombosis in guinea pigs with epithelial damage in the jugular vein?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4615 (156/1000)
#   Pregunta: What is the significance of marking gel foam particles with 99mTc in catheter embolisation procedures?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4676 (157/1000)
#   Pregunta: What were the clinical findings and outcomes in the case of an 8-month-old girl who developed generalized progressive vaccinia after smallpox vaccination in 1968?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4782 (158/1000)
#   Pregunta: What were the findings of the electron microscopy study on two cases of cellular angiomas in infants?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4787 (159/1000)
#   Pregunta: What advancements have been made in the design of bipolar coagulation forceps to improve coagulation effectiveness and reduce tissue damage?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4789 (160/1000)
#   Pregunta: What clinical findings were observed in the 22-year-old woman with a persistent primitive epithelial papilla?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 4794 (161/1000)
#   Pregunta: What is the significance of the assay method for measuring methylmalonyl-CoA mutase activity in leukocytes?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4813 (162/1000)
#   Pregunta: What were the effects of experimental folacin deficiency on the uptake and distribution of radioactive folic acid in rats?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 4816 (163/1000)
#   Pregunta: What are the characteristics and diagnostic methods associated with corneal dystrophies?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 4819 (164/1000)
#   Pregunta: What happens to newborn mice that survive an infection with an attenuated herpes simplex virus in terms of their resistance to a pathogenic strain of the virus?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4850 (165/1000)
#   Pregunta: What were the findings regarding vascular permeability and enzyme activity in brain specimens from patients with meningioma?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4854 (166/1000)
#   Pregunta: What percentage of hospitalized children at Arthur Davidson Children's Hospital in 1974-75 had airborne infections, and what were some of the leading causes of mortality?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 4863 (167/1000)
#   Pregunta: What were the observed cardiac effects in atropinized dogs compared to non-atropinized dogs during anesthetic induction?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 4866 (168/1000)
#   Pregunta: What were the effects observed in mice after 36 weeks of exposure to safrole in terms of liver lesions and iron reactions?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5035 (169/1000)
#   Pregunta: What does power spectral analysis reveal about the EEG activity of the area postrema and the anterior raphé region during slow-wave sleep in cats?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5054 (170/1000)
#   Pregunta: What congenital defect was identified as the cause of impaired mucociliary clearance and immotile sperm in three siblings with chronic respiratory disease?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5140 (171/1000)
#   Pregunta: What role does insulin play in the regulation of human adipose tissue lipoprotein lipase activity, particularly in the context of diabetes and obesity?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5146 (172/1000)
#   Pregunta: Which cephalosporin demonstrated significantly higher interstitial fluid levels compared to cephaloridine and cefamandole, indicating it is the preferred drug due to its superior extravascular penetration?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5152 (173/1000)
#   Pregunta: What occurs in the late stages of cardiomyopathy in Syrian hamsters that contributes to congestive heart failure?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5158 (174/1000)
#   Pregunta: What were the findings regarding the relationship between the EMI number and the linear absorption coefficient in the evaluation of the EMI scanner's calibration and response?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5159 (175/1000)
#   Pregunta: What did chromosome analysis reveal about the rate of aberrations among workers with vinyl chloride illness, an angiosarcoma case, and exposed animals compared to control groups?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5167 (176/1000)
#   Pregunta: What is the origin and function of the accessory phrenic nerve in rats compared to the main phrenic nerve?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5189 (177/1000)
#   Pregunta: What are the findings regarding the prevalence of hepatitis B virus infections among different age groups in Liberia?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5196 (178/1000)
#   Pregunta: What happens to the fermentation of nucleosides and purines in Peptococcus prévotii during starvation, and how can this effect be mitigated?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5198 (179/1000)
#   Pregunta: What were the findings regarding hepatitis A and B antibody prevalence in five South Pacific island populations, particularly in Ponape, over the years?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5215 (180/1000)
#   Pregunta: What did a study reveal about the relationship between textile work and oral or pharyngeal cancer in patients from the North-west and West Yorkshire regions of England?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5231 (181/1000)
#   Pregunta: What effect does TSH have on the transfer of newly synthesized protein from thyroid follicle cells to the follicle lumen?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5243 (182/1000)
#   Pregunta: What are the benefits of the new valvuloplastic esophagogastrostomy technique in proximal gastrectomy compared to traditional anastomosis methods?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5251 (183/1000)
#   Pregunta: What is the mortality rate for patients with penetrating injuries to the iliac arteries within thirty days, despite various surgical management techniques?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5312 (184/1000)
#   Pregunta: What are the comparative effects of N-acetylprocainamide and procainamide on isolated rat atria?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5341 (185/1000)
#   Pregunta: What did the study reveal about the relationship between the mitochondrial malic enzyme gene (Mod-2) expression in mice and factors such as gene duplication and X-inactivation?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5405 (186/1000)
#   Pregunta: What percentage of children experience mucogingival problems, and what treatment is recommended when there is 1 mm or less of keratinized tissue, particularly before orthodontic treatment?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5413 (187/1000)
#   Pregunta: What demographic group exhibited significant seasonal variation in the diagnosis of insulin-dependent diabetes, particularly in autumn and winter, according to a study conducted between 1964 and 1977?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5414 (188/1000)
#   Pregunta: What effect does the addition of barium sulfate in concentrations of 5% to 60% have on the polymerization temperature and shear strength of surgical simplex P?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5536 (189/1000)
#   Pregunta: What is the mechanism by which methyldopa reduces blood pressure?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5561 (190/1000)
#   Pregunta: What did the study reveal about the relationship between tactile perception and academic performance in children with and without brain impairments?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5567 (191/1000)
#   Pregunta: What does the paper discuss regarding the use of hospital work rounds in teaching practicing physicians?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5580 (192/1000)
#   Pregunta: What did a study of 54 patients with gastrointestinal hemorrhage related to portal hypertension reveal about the cause of bleeding identified by fibroscopy?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5621 (193/1000)
#   Pregunta: What observation is made regarding dihydrodipicolinate synthase activity in Bacillus subtilis ribonucleic acid polymerase mutants during late sporulation?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5666 (194/1000)
#   Pregunta: What is the effect of intravenous glucose infusion on insulin secretion in lactating cows, particularly comparing normal, ketonemic, and starved cows?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5668 (195/1000)
#   Pregunta: What was the outcome for the 50-year-old woman with retroperitoneal paraganglioma and nephrotic syndrome after tumor removal, and what significance does this case hold in medical literature?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5695 (196/1000)
#   Pregunta: What is the significance of the hepatic circulation in homeostatic functions and how does it respond to changes in blood volume?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5720 (197/1000)
#   Pregunta: What are the effects of destroying the temporal neocortex or amygdala in monkeys in relation to Klüver-Bucy syndrome?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5726 (198/1000)
#   Pregunta: What are the effects of exposing normal rabbit lenses to antilens and antiuveoretina antibodies in relation to cataract development?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5745 (199/1000)
#   Pregunta: How does mouse hepatitis virus (MHV-3) affect immune responsiveness in relation to circulating interferon levels?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5775 (200/1000)
#   Pregunta: What were the findings and outcomes in a case of a 26-week pregnancy complicated by hydramnios and a male fetus with a large sacrococcygeal teratoma?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5794 (201/1000)
#   Pregunta: What were the findings regarding the effectiveness of double preoperative intralesional BCG injections compared to single doses in Fischer 344 female rats with 13762 mammary adenocarcinoma?
#   ID de respuesta predicho por Llama: 2
#
# Procesando Pregunta ID: 5803 (202/1000)
#   Pregunta: What were the effects of chronic cerebellar stimulation on respiratory muscle coordination in a patient with cerebral palsy?
#   ID de respuesta predicho por Llama: 3
#
# Procesando Pregunta ID: 5817 (203/1000)
#   Pregunta: What effect does instructional set have on the concreteness of responses in schizophrenic patients compared to organic and neurotic patients during a proverbs task?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5854 (204/1000)
#   Pregunta: What effect does aminophylline infusion have on pacing-induced changes in coronary blood flow and resistance in anesthetized dogs?
#   ID de respuesta predicho por Llama: 0
#
# Procesando Pregunta ID: 5860 (205/1000)
#   Pregunta: What were the effects of irradiation on lipid oxidation and organoleptic acceptability in herring and redfish?
#   ID de respuesta predicho por Llama: 1
#
# Procesando Pregunta ID: 5879 (206/1000)
# ...
# Pregunta ID: 15347, Predicción ID: 3
# Pregunta ID: 15353, Predicción ID: 2
# Pregunta ID: 15417, Predicción ID: 2
# Pregunta ID: 15430, Predicción ID: 3
# Pregunta ID: 15446, Predicción ID: 0
# Pregunta ID: 15478, Predicción ID: 2
# Pregunta ID: 15494, Predicción ID: 3
# Pregunta ID: 15500, Predicción ID: 3
# Pregunta ID: 15514, Predicción ID: 0
# Pregunta ID: 15531, Predicción ID: 3
# Pregunta ID: 15550, Predicción ID: 3
# Pregunta ID: 15573, Predicción ID: 3
# Pregunta ID: 15672, Predicción ID: 1
# Pregunta ID: 15718, Predicción ID: 2
# Pregunta ID: 15734, Predicción ID: 1
# Pregunta ID: 15798, Predicción ID: 3
# Pregunta ID: 15804, Predicción ID: 3
# Pregunta ID: 15823, Predicción ID: 0
# Pregunta ID: 15830, Predicción ID: 3
# Pregunta ID: 15837, Predicción ID: 0
# Pregunta ID: 15894, Predicción ID: 1
# Pregunta ID: 15898, Predicción ID: 3
# Pregunta ID: 15929, Predicción ID: 1
# Pregunta ID: 16035, Predicción ID: 3
# Pregunta ID: 16066, Predicción ID: 1
# Pregunta ID: 16067, Predicción ID: 1
# Pregunta ID: 16096, Predicción ID: 0
# Pregunta ID: 16097, Predicción ID: 3
# Pregunta ID: 16098, Predicción ID: 1
# Pregunta ID: 16198, Predicción ID: 3
# Pregunta ID: 16210, Predicción ID: 3
# Pregunta ID: 16218, Predicción ID: 3
# Pregunta ID: 16291, Predicción ID: 2
# Pregunta ID: 16364, Predicción ID: 1
# Pregunta ID: 16368, Predicción ID: 3
# Pregunta ID: 16392, Predicción ID: 3
# Pregunta ID: 16422, Predicción ID: 2
# Pregunta ID: 16439, Predicción ID: 0
# Pregunta ID: 16457, Predicción ID: 2
# Pregunta ID: 16458, Predicción ID: 1
# Pregunta ID: 16482, Predicción ID: 2
# Pregunta ID: 16489, Predicción ID: 1
# Pregunta ID: 16499, Predicción ID: 3
# Pregunta ID: 16505, Predicción ID: 1
# Pregunta ID: 16555, Predicción ID: 1
# Pregunta ID: 24807, Predicción ID: 2
# Pregunta ID: 24853, Predicción ID: 2
# Pregunta ID: 24860, Predicción ID: 2
# Pregunta ID: 24882, Predicción ID: 1
# Pregunta ID: 24904, Predicción ID: 2
# Pregunta ID: 24990, Predicción ID: 3
# Pregunta ID: 25050, Predicción ID: 1
# Pregunta ID: 25052, Predicción ID: 1
# Pregunta ID: 25053, Predicción ID: 3
# Pregunta ID: 25056, Predicción ID: 1
# Pregunta ID: 25071, Predicción ID: 1
# Pregunta ID: 25097, Predicción ID: 1
# Pregunta ID: 25101, Predicción ID: 2
# Pregunta ID: 25167, Predicción ID: 3
# Pregunta ID: 25178, Predicción ID: 2
# Pregunta ID: 25179, Predicción ID: 0
# Pregunta ID: 25216, Predicción ID: 1
# Pregunta ID: 25231, Predicción ID: 3
# Pregunta ID: 25273, Predicción ID: 2
# Pregunta ID: 25323, Predicción ID: 3
# Pregunta ID: 25333, Predicción ID: 3
# Pregunta ID: 25457, Predicción ID: 3
# Pregunta ID: 25480, Predicción ID: 2
# Pregunta ID: 25492, Predicción ID: 2
# Pregunta ID: 25537, Predicción ID: 2
# Pregunta ID: 25546, Predicción ID: 2
# Pregunta ID: 25569, Predicción ID: 1
# Pregunta ID: 25571, Predicción ID: 1
# Pregunta ID: 25580, Predicción ID: 3
# Pregunta ID: 25608, Predicción ID: 1
# Pregunta ID: 25616, Predicción ID: 3
# Pregunta ID: 25671, Predicción ID: 2
# Pregunta ID: 25710, Predicción ID: 3
# Pregunta ID: 25752, Predicción ID: 1
# Pregunta ID: 25795, Predicción ID: 1
# Pregunta ID: 25820, Predicción ID: 1
# Pregunta ID: 25849, Predicción ID: 2
# Pregunta ID: 25884, Predicción ID: 2
# Pregunta ID: 25906, Predicción ID: 2
# Pregunta ID: 25908, Predicción ID: 1
# Pregunta ID: 25940, Predicción ID: 1
# Pregunta ID: 25975, Predicción ID: 2
# Pregunta ID: 25978, Predicción ID: 0
# Pregunta ID: 25981, Predicción ID: 1
# Pregunta ID: 26007, Predicción ID: 2
# Pregunta ID: 26011, Predicción ID: 0
# Pregunta ID: 26047, Predicción ID: 2
# Pregunta ID: 26169, Predicción ID: 3
# Pregunta ID: 26170, Predicción ID: 3
# Pregunta ID: 26178, Predicción ID: 2
# Pregunta ID: 26205, Predicción ID: 1
# Pregunta ID: 26211, Predicción ID: 3
# Pregunta ID: 26214, Predicción ID: 0
# Pregunta ID: 26216, Predicción ID: 1
#
# Resultados completos guardados en: /content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/rag_test_predictions.json
#
# --- Proceso Completado ---

# %%
import pandas as pd
# Save results to CSV
results_csv_output_path = "/content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/rag_test_predictions.csv"
results_df = pd.DataFrame(results)
results_df.to_csv(results_csv_output_path, index=False)
print(f"\nResultados completos guardados en: {results_csv_output_path}")
# Out:
# Resultados completos guardados en: /content/drive/MyDrive/UniAndes/MAIA-202411/3. modelos-avanzados-para-el-procesamiento-de-lenguaje-natural/W7/maia-pln-2025/rag_test_predictions.csv
